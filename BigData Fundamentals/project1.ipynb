# %%
import numpy as np 
import pandas as pd 
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student-mat.csv", sep=";")

# %%
df
# Out:
#      GP  F  18  U  GT3  A  4  4.1   at_home   teacher  ... 4.2  3  4.3  1  \
# 0    GP  F  17  U  GT3  T  1    1   at_home     other  ...   5  3    3  1
# 1    GP  F  15  U  LE3  T  1    1   at_home     other  ...   4  3    2  2
# 2    GP  F  15  U  GT3  T  4    2    health  services  ...   3  2    2  1
# 3    GP  F  16  U  GT3  T  3    3     other     other  ...   4  3    2  1
# 4    GP  M  16  U  LE3  T  4    3  services     other  ...   5  4    2  1
# ..   .. ..  .. ..  ... .. ..  ...       ...       ...  ...  .. ..  ... ..
# 389  MS  M  20  U  LE3  A  2    2  services  services  ...   5  5    4  4
# 390  MS  M  17  U  LE3  T  3    1  services  services  ...   2  4    5  3
# 391  MS  M  21  R  GT3  T  1    1     other     other  ...   5  5    3  3
# 392  MS  M  18  R  LE3  T  3    2  services     other  ...   4  4    1  3
# 393  MS  M  19  U  LE3  T  1    1     other   at_home  ...   3  2    3  3
#
#      1.1 3.1   6   5 6.1 6.2
# 0      1   3   4   5   5   6
# 1      3   3  10   7   8  10
# 2      1   5   2  15  14  15
# 3      2   5   4   6  10  10
# 4      2   5  10  15  15  15
# ..   ...  ..  ..  ..  ..  ..
# 389    5   4  11   9   9   9
# 390    4   2   3  14  16  16
# 391    3   3   3  10   8   7
# 392    4   5   0  11  12  10
# 393    3   5   5   8   9   9
#
# [394 rows x 33 columns]

# %%
from sklearn import preprocessing
category_cols = list(df.select_dtypes(include = ['object']).columns)
for col in category_cols:
    le = preprocessing.LabelEncoder()
    df[col]=le.fit_transform(df[col])

# %%
f,ax = plt.subplots(figsize=(12, 10))
cols = df.corr().abs().index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()
# cols = cols.drop('Transported')
print(cols)
# Out:
# Index(['GP', 'F', '18', 'U', 'GT3', 'A', '4', '4.1', 'at_home', 'teacher',
#        'course', 'mother', '2', '2.1', '0', 'yes', 'no', 'no.1', 'no.2',
#        'yes.1', 'yes.2', 'no.3', 'no.4', '4.2', '3', '4.3', '1', '1.1', '3.1',
#        '6', '5', '6.1', '6.2'],
#       dtype='object')
